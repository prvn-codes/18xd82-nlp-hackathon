# %% [markdown]
# # NLP Hackathon

# %% [markdown]
# ### Package import handling

# %%
import pandas as pd
import numpy as np
import glob
import shutil

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ##### Combining all data files into one

# %%
combineFile = 'data.txt'

with open(combineFile,'wb') as wf:
    for filename in glob.glob('data_files/*.txt'):
        if filename == combineFile:
            continue
        with open(filename,'rb') as rf:
            shutil.copyfileobj(rf,wf)

# %%
with open('data.txt',encoding = 'unicode_escape') as file:
    data = file.read()

# %% [markdown]
# ##### Regexing all user roles and stories

# %%
import regex as re

# %%
# removing empty newlines
regex = r"(\n)\n+"
subst = "\\n"

data = re.sub(regex, subst, data, 0, re.MULTILINE)

# %% [markdown]
# ### Solutions

# %% [markdown]
# ##### 1 ) Automatic generation user stories for different stakeholders /roles
#
# a. Role based Stories extraction can be done using regular expression
#
# b. The different stakeholders involved in the corpus are data manager, PI, IT manager, ITstaff member, researcher, repository manager etc.

# %%
regex = r"As\s[a-z]+\s([^,]+),\s(.*)[\n]"

matches = re.finditer(regex, data, re.MULTILINE)

data_list = []

for matchNum, match in enumerate(matches, start=1):    
    #print(match.group(1),match.group(2))
    data_list.append([match.group(1).lower(),match.group(2).lower()])

data_list
# Out:
# [['data user', 'i want to have the 12-19-2017 deletions processed.'],
#  ['ui designer',
#   'i want to redesign the resources page, so that it matches the new broker design styles.'],
#  ['ui designer',
#   'i want to report to the agencies about user testing, so that they are aware of their contributions to making broker a better ux.'],
#  ['ui designer',
#   'i want to move on to round 2 of dabs or fabs landing page edits, so that i can get approvals from leadership.'],
#  ['ui designer',
#   'i want to move on to round 2 of homepage edits, so that i can get approvals from leadership.'],
#  ['ui designer',
#   'i want to move on to round 3 of the help page edits, so that i can get approvals from leadership.'],
#  ['developer ',
#   'i want to be able to log better, so that i can troubleshoot issues with particular submissions and functions.'],
#  ['developer',
#   'i want to add the updates on a fabs submission to be modified when the publishstatus changes, so that i know when the status of the submission has changed.'],
#  ['devops engineer',
#   'i want new relic to provide useful data across all applications.'],
#  ['ui designer',
#   ' i want to move on to round 2 of the help page edits, so that i can get approvals from leadership.'],
#  ['ui designer',
#   'i want to move on to round 2 of homepage edits, so that i can get approvals from leadership.'],
#  ['broker user',
#   'i want to upload and validate the error message to have accurate text.'],
#  ['broker user',
#   "i want the d1 file generation to be synced with the fpds data load, so that i don't have to regenerate a file if no data has been updated."],
#  ['website user',
#   'i want to access published fabs files, so that i can see the new files as they come in.'],
#  ['owner',
#   'i want to be sure that usaspending only send grant records to my system.'],
#  ['developer',
#   'i want to update the broker validation rule table to account for the rule updates in db-2213.'],
#  ['developer',
#   'i want to add the gtas window data to the database, so that i can ensure the site is locked down during the gtas submission period.'],
#  ['developer',
#   'i want d files generation requests to be managed and cached, so that duplicate requests do not cause performance issues.'],
#  ['user',
#   'i want to access the raw agency published files from fabs via usaspending.'],
#  ['agency user',
#   'i want to be able to include a large number of flexfields without performance impact.'],
#  ['broker user',
#   'i want  to help create content mockups, so that i can submit my data efficiently.'],
#  ['ui designer',
#   'i want to track the issues that come up in tech thursday, so that i know what to test and what want s to be fixed.'],
#  ['owner',
#   'i want to create a user testing summary from the ui sme, so that i can know what ui improvements we will follow through on.'],
#  ['ui designer',
#   'i want to begin user testing, so that i can validate stakeholder ui improvement requests.'],
#  ['ui designer',
#   'i want to schedule user testing, so that i can give the testers advanced notice to ensure buy-in.'],
#  ['owner',
#   'i want to design a schedule from the ui sme, so that i know the potential timeline of the ui improvements wanted.'],
#  ['owner',
#   'i want to design an audit from the ui sme, so that i know the potential scope of the ui improvements want ed.'],
#  ['developer',
#   'i want to prevent users from double publishing fabs submissions after refreshing, so that there are no duplicates.'],
#  ['data user', 'i want to receive updates to fabs records.'],
#  ['agency user',
#   'i want to be able to include a large number of flexfields without performance impact.'],
#  ['developer ',
#   'i want to update the fabs sample file to remove fundingagencycode after fabs is updated to no longer require the header.'],
#  ['agency user',
#   'i want to ensure that deleted fsrs records are not included in submissions.'],
#  ['website user', 'i want to see updated financial assistance data daily.'],
#  ['user',
#   'i want the publish button in fabs to deactivate after i click it while the derivations are happening, so that i cannot click it multiple times for the same submission.'],
#  ['developer ',
#   "i want to ensure that attempts to correct or delete non-existent records don't create new published data."],
#  ['owner',
#   'i want to reset the environment to only take staging max permissions, so that i can ensure that the fabs testers no longer have access.'],
#  ['user',
#   'i want the flexfields in my submission file to appear in the warning and error files when the only error is a missing required element.'],
#  ['user',
#   'i want to have accurate and complete data related to ppopcode and ppopcongressionaldistrict.'],
#  ['agency user',
#   'i want the fabs validation rules to accept zero and blank for loan records.'],
#  ['agency user',
#   'i want fabs deployed into production, so i can submit my financial assistance data.'],
#  ['developer ',
#   'i want to clarify to users what exactly is triggering the cfda error code in each case.'],
#  ['agency user',
#   'i want to be confident that the data coming from sam is complete.'],
#  ['developer ',
#   'i want my domain models to be indexed properly, so that i can get validation results back in a reasonable amount of time.'],
#  ['agency user',
#   'i want the fabs validation rules to accept zero and blank for non-loan records.'],
#  ['broker team member',
#   'i want to make some updates to the sql codes for clarity.'],
#  ['agency user', 'i want to have all derived data elements derived properly.'],
#  ['broker team member',
#   'i want to add the 00***** and 00forgn ppopcode cases to the derivation logic.'],
#  ['data user',
#   'i want to see the office names derived from office codes, so that i can have appropriate context for understanding them.'],
#  ['broker user',
#   'i want the historical fabs loader to derive fields, so that my agency codes are correct in the publishedawardfinancialassistance table.'],
#  ['broker team member',
#   'i want to ensure the broker resources, validations, and p&p pages are updated appropriately for the launch of fabs and daims v1.1.'],
#  ['developer',
#   'i want the data loaded from historical fabs to include the frec derivations, so that i can have consistent frec data for usaspending.gov.'],
#  ['user', "i don't want to see nasa grants displayed as contracts."],
#  ['user',
#   'i want the duns validations to accept records whose actiontypes are b, c, or d and the duns is registered in sam, even though it may have expired. '],
#  ['user',
#   'i want the duns validations to accept records whose actiondates are before the current registration date in sam, but after the initial registration date.'],
#  ['broker team member',
#   'i want to derive fundingagencycode, so that the data quality and completeness improves.'],
#  ['agency user',
#   'i want the maximum length allowed for legalentityaddressline3 to match schema v1.1.'],
#  ['agency user', 'i want to use the schema v1.1 headers in my fabs file.'],
#  ['agency user',
#   'i want to map the federalactionobligation properly to the atom feed.'],
#  ['broker user',
#   'i want to have ppopzip+4 work the same as the legal entity zip validations.'],
#  ['fabs user',
#   'i want to link the sample file on the "what you want  to submit" dialog to point to the correct file, so that i have an accurate reference for my agency submissions.'],
#  ['agency user', 'i want fpds data to be up-to-date daily.'],
#  ['user',
#   'i want to access the raw agency published files from fabs via usaspending.'],
#  ['developer ',
#   'i want to determine how agencies will generate and validate d files from fabs and fpds data.'],
#  ['user', 'i want to generate and validate d files from fabs and fpds data.'],
#  ['agency user',
#   'i want the header information box to show updated date and time, so that i know when it was updated.'],
#  ['agency user',
#   'i want to receive a more helpful file-level error when i upload a file with the wrong extension.'],
#  ['tester',
#   'i want to have access to test features in environments other than staging, so that i can test any nonprod feature in any environment.'],
#  ['fabs user',
#   "i want to submission errors to accurately represent fabs errors, so that i know why my submission didn't work."],
#  ['fabs user',
#   "i want the frontend urls to more accurately reflect the page i'm accessing, so that i'm not confused."],
#  ['agency user',
#   'i want all historical financial assistance data loaded for fabs go-live.'],
#  ['developer ',
#   'i want the historical fpds data loader to include both extracted historical data and fpds feed data.'],
#  ['agency user', 'i want historical fpds data loaded.'],
#  ['agency user',
#   "i want to accurately see who created a submission, so that i'm not confused about who last updated a submission."],
#  ['agency user', 'i want to get file f in the correct format.'],
#  ['agency user', 'i want to better understand my file-level errors.'],
#  ['developer ',
#   'i want to provide fabs groups that function under the frec paradigm.'],
#  ['tester',
#   'i want to ensure that fabs is deriving fields properly through a robust test file plus a follow up check.'],
#  ['owner', 'i only want zero-padded fields, so that i can justify padding.'],
#  ['broker user',
#   'i want to submit records for individual recipients without receiving a duns error.'],
#  ['user',
#   'i want more information about how many rows will be published prior to deciding whether to publish.'],
#  ['developer',
#   'i want to prevent duplicate transactions from being published and deal with the time gap between validation and the publishing decision.'],
#  ['fabs user',
#   'i want to submit a citywide as a ppopzip and pass validations.'],
#  ['broker user',
#   'i want to have updated error codes that accurately reflect the logic and provide enough information, so that i can fix my submission.'],
#  ['agency user',
#   'i want to leave off the last 4 digits of the zip without an error, so that i can complete my submissions.'],
#  ['fabs user',
#   'i want to make sure the historical data includes all necessary columns, so that the information in the database is correct.'],
#  ['data user',
#   'i want to access two additional fields from the fpds data pull.'],
#  ['fabs user',
#   'i want additional helpful info in the submission dashboard, so that i can better manage submissions and ig requests.'],
#  ['fabs user',
#   'i want to download the uploaded fabs file, so that i can get the uploaded file.'],
#  ['developer i want to quickly access broker application data',
#   'so that i can investigate issues.'],
#  ['developer ',
#   'i want to determine the best way to load historical fpds data, so that i can load all fpds data since 2007.'],
#  ['fabs user',
#   'i want the language on fabs pages to be appropriate for me, so that i am not confused.'],
#  ['fabs user',
#   'i do not want  dabs banner messages and vice versa, so that i have the appropriate information for my application.'],
#  ['fabs user',
#   'i want to have read-only access to dabs, so that i can view dabs pages without wanting two sets of permissions.'],
#  ['fabs user',
#   'i want to have my validations run in a reasonable amount of time.'],
#  ['fabs user',
#   'i want to see correct status labels on the submission dashboard, so that i can quickly see my submission history.'],
#  ['agency user',
#   'i want to know when the submission periods start and end, so that i know when the submission starts and ends.'],
#  ['agency user',
#   'i want a landing page to navigate to either fabs or dabs pages, so that i can access both sides of the site.'],
#  ['agency user',
#   "i want to submit my data elements surrounded by quotation marks, so that excel won't strip off leading and trailing zeroes.as a public user, i want to search for information, so that i can obtain publicly available information concerning properties, county services, processes and other general information."],
#  ['prospectiveapplicant',
#   'i want to research requirements and to select a service, so that i can find the relevant service and/or application type to initiate via the online portal.'],
#  ['applicant',
#   'i want to request preapplication assistance, so that i can receive a response to a request for a meeting or information that is a result of the preapplication assistance.'],
#  ['customer',
#   'i want to create a customer portal user account, so that i can log on to the customer portal and perform transactions that first require user authentication.'],
#  ['applicant',
#   'i want to submit application, so that i can provide my information, plans and/or documents to initiate a transaction with the county.'],
#  ['applicant',
#   'i want to submit supporting documentation, so that i can satisfy documentation requirements for my application.'],
#  ['applicant',
#   'i want to pay fee, so that i can satisfy outstanding charge associated with the service requested or received from the county.'],
#  ['applicant',
#   'i want to check the status of a transaction, so that i can understand where the provisioning of my service is in the process, such as information related to service levels, fees, plan review, permit, or inspection results.'],
#  ['applicant',
#   'i want to modify my application, so that i can successfully change information on an application.'],
#  ['staff member',
#   'i want to perform a completeness review, so that i can validate when an application is complete and eligible for further technical review.'],
#  ['staff member',
#   'i want to record an internal note, so that i can share information with other staff collaborating on the record.'],
#  ['staff member',
#   'i want to assign an application for detailed review, so that i can review the for compliance and subsequently approved or denied.'],
#  ['staff member',
#   'i want to apply a hold, so that i can prevent progression through the workflow or other actions in the system until the issue is resolved.'],
#  ['staff member',
#   'i want to remove a hold, so that i can allow progression through the workflow or other actions in the system now that the issue has been resolved.'],
#  ['staff member',
#   'i want to send a formal response to applicant, so that i can satisfy communication and records responsibilities.'],
#  ['staff member',
#   'i want to track  the draft proffers, so that i can preserve the history of draft proffer statements submitted by the applicant.'],
#  ['staff member',
#   'i want to manage approved proffers, so that i can ensure compliance with and satisfaction of the proffer in the future.'],
#  ['staff member',
#   'i want to manage ordinances, so that i can maintain accurate ordinance information in the system.'],
#  ['staff member',
#   'i want to schedule a meeting, so that i can bring the required parties together at a specific date/time to address an issue.'],
#  ['staff member',
#   'i want to denote an application with a final action status. so that i can finish it.'],
#  ['planning staff member',
#   'i want to conduct and track plan amendments and planning studies, so that i can record work in process, outcome, and location-based information related to the plan(s).'],
#  ['planning staff member',
#   'i want to generate planning-related reports, so that i can access, analyze and/or export the needed information in the format i requested.'],
#  ['planning staff member',
#   'i want to evaluate consistency with the comprehensive plan, so that i can complete my required review of a plan set and/or application.'],
#  ['staff member',
#   'i want to perform a staff review, so that i can validate compliance of an application with the zoning ordinance and impact approval/denial of the application accordingly.'],
#  ['zoning staff member',
#   'i want to process the requests for zoning information, so that i can capture my response to the request in the system and also send a communication from the system to the applicant.'],
#  ['zoning staff member',
#   "i want to issue the zoning-related permits, so that i can satisfy an applicant's request for service that has proven to be eligible and in compliance with the zoning ordinance."],
#  ['staff member',
#   'i want to develop a staff report, so that i can publish and distribute the report according to business rules.'],
#  ['staff member',
#   'i want to manage hearing calendars, so that i can track hearing-related activities and due dates.'],
#  ['staff member',
#   'i want to assign a hearing date, so that i can present the application to the appropriate governing body within the timelines dictated by the relevant county rules and procedures.'],
#  ['staff member',
#   'i want to manage affidavits, so that i can ensure compliance with the requirements prior to the hearing.'],
#  ['applicant',
#   'i want to satisfy hearing requirements, so that i can ensure all pre-hearing requirements are satisfied in time for the hearing.'],
#  ['staff member',
#   'i want to prepare for and support hearing execution, so that i can ensure all pre-hearing requirements are satisfied and staff and applicant are ready for the hearing.'],
#  ['staff member',
#   'i want to capture a hearing decision, so that i can enforce the system.'],
#  ['staff member',
#   'i want to process the appeals, so that i can track the outcome and record the impact on the relevant records.'],
#  ['plan review staff member',
#   'i want to assign plans for review, so that i can ensure plans have been assigned to the appropriate plan reviewer.'],
#  ['plan review staff supervisor',
#   'i want to manage plan reviewer workload, so that i can monitor and effectively adjust workload as necessary and ensure service levels are met'],
#  ['applicant',
#   'i want to request a plan review meeting, so that i can meet with the plan review staff regarding the plan review.'],
#  ['plan review staff member',
#   'i want to successfully conduct a plan review meeting with the applicant and record the outcome, so that i can listen to it again.'],
#  ['plan review staff member',
#   'i want to review plans, so that i can review them for compliance and either approve, or fail or deny the plans and record any conditions, clearances, or corrections needed from the applicant.'],
#  ['applicant',
#   'i want to resubmit plans, so that i can review revised plans. '],
#  ['plan review staff member',
#   'i want to review the code modifications submitted by the applicant, so that i can review the request and if approved, associate it with the appropriate project.'],
#  ['plan review staff member',
#   'i want to track the completion of required plan reviews, so that i can ensure all plan review tasks are completed, results have been sent to the applicant and any downstream steps are initiated such has a final review or payment for permit issuance.'],
#  ['development staff member',
#   'i want to issue a development-related permit, so that i can grant the request to the applicant to begin work'],
#  ['staff member',
#   'i want to manage bonds, so that i can track and manage bonds throughout the lifecycle of the project until release.'],
#  ['applicant',
#   'i want to complete building development project, so that i can receive any posted bond and/or obtain occupancy.'],
#  ['applicant',
#   'i want to complete building development project, so that i can receive any posted bond and/or obtain occupancy.'],
#  ['customer',
#   'i want to request inspection, so that a county inspector is assigned to perform an inspection of my project.'],
#  ['inspection staff member',
#   'i want to create an inspection, so that i can schedule and assign the inspection.'],
#  ['inspection staff supervisor',
#   'i want to assign inspections, so that i can make sure the appropriate inspector receives the work.'],
#  ['inspection supervisor',
#   'i want to manage inspector workload, so that i can meet service level and quality requirements.'],
#  ['inspector',
#   'i want to conduct inspections, so that i can validate customer compliance with code and regulations and provide results of the inspection to the customer.'],
#  ['enforcement staff member',
#   'i want to issue a notice of violation, so that i can provide formal communication to the responsible party.'],
#  ['l staff member',
#   'i want to search for property information, so that i can obtain all associated current and historic owners, permits, and applications.'],
#  ['staff member',
#   'i need to be notified when geospatial attributes change, so that i can ensure that i am reviewing the permit/application to the most current data and appropriate standards.'],
#  ['county staff member',
#   'i want to create a custom query/report outside of the common querying/reporting functionality, so that i can fulfill a request.'],
#  ['staff member',
#   'i want to create each condo unit, so that i can associate it to the child parcel and address after the condominiums are recorded in the system.'],
#  ['technical staff member',
#   'i want to update the gis property management, so that i can successfully update the transactional parcel pin to reference the gis layer where the split or merged parcel pin exists.'],
#  ['staff member',
#   'i want to send or post citations and fines, so that i can successfully send the notice of violation document to the property owner and log information about the action.as a user, i want to click on the address, so that it takes me to a new tab with google maps.'],
#  ['user',
#   'i want to be able to anonymously view public information, so that i know about recycling centers near me before creating an account.'],
#  ['user',
#   'i want to be able to enter my zip code and get a list of nearby recycling facilities, so that i can determine which ones i should consider.'],
#  ['user',
#   'i want to be able to get the hours of each recycling facility, so that i can arrange drop-offs on my off days or during after-work hours.'],
#  ['user',
#   'i want to have a flexible pick up time, so that i can more conveniently use the website.'],
#  ['user',
#   'i want to be able to select different types of recyclable waste, so i have and get a list of facilities that accept each type and their opening hours, so that i can find an optimal route and schedule.'],
#  ['user',
#   'i want to add donation centers as favorites on my profile, so that i can view them later.'],
#  ['user',
#   'i want to be able to give my email id, so that i can receive notifications for new events as they are posted.'],
#  ['user',
#   'i want to be able to view a map display of the public recycling bins around my area.'],
#  ['user',
#   'i want to be able to view a map display of the special waste drop off sites around my area.'],
#  ['user',
#   'i want to be able to view the safe disposal events currently being organised around my area.'],
#  ['user',
#   'i want to choose a flexible pick up time, so that i can more conveniently use the website.'],
#  ['user',
#   'i want to view user documentation for the website, so that i know how to use the web app.'],
#  ['user', 'i want to get feedback when i enter an invalid zip code.'],
#  ['user',
#   'i want to be able to create an acocunt, so that i can create my own profile.'],
#  ['admin',
#   "i want to be able to add or remove recycling facilities' information, so that users get the most recent information."],
#  ['admin',
#   "i want to be able to read users' feedback and complaints, so that we can add more features and keep improving the service we provide to them."],
#  ['user',
#   'i want to be able to check transaction history and keep a record of it, so that i can go back when needed.'],
#  ['user',
#   'i want to have a great ui and ux from the sites, so that i have a pleasant experience when navigating through them.'],
#  ['user',
#   'i want to be able to access the site and do all the other stuffs on all of my electronic devices.'],
#  ['admin',
#   'i want to be able to block specific users based on ip address, so that i can prevent spamming on the websites.'],
#  ['admin',
#   "i want to view a dashboard that monitors all the sites' statuses, so that i can have a sense of what people are doing on our sites and know the service status."],
#  ['admin',
#   'i want to have all data encrypted, so that important information will not be stolen during a server breach or an attack.'],
#  ['executive',
#   "i want to have full access to data related to my company, so that i can have a sense of my company's performance."],
#  ['employee',
#   'i want to access the route planning system during work, so that i can be guided through the neighbourhood.'],
#  ['employee from the hr department',
#   'i want to have access to the full information of all employees working for this business.'],
#  ['developer',
#   'i want to access an api from the website, so that i can integrate it and implement certain features in my own ios application.'],
#  ['user',
#   'i want to be able to receive tempting rewards, so that i have a reason to use the website.'],
#  ['user',
#   'i want to have my personal information kept securely in the database of the website, so that i will not suffer from identity theft or telephone harassment.'],
#  ['admin',
#   "i want to handle all users' activities, so that i can manage more efficiently."],
#  ['company',
#   'i want to have a website that is easy to use, so that i can upload or delete stuff step by step.'],
#  ['employee',
#   'i want to get quick notifications, so that i can process cases the first time.'],
#  ['company accountant',
#   'i want to view all available activity fees online, so that i can easily create a bill statement.'],
#  ['developer',
#   'i want to use bootstrap in the process of developing, so that i can easily design my website.'],
#  ['developer',
#   'i want to attend some ui/ux lessons, so that i can develop an awesome and beautiful features website.'],
#  ['user',
#   'i want to view all locations of recycling centers on a map, so that i can check which routes to take to drop off waste.'],
#  ['user',
#   "i want to upload my week's schedule, so that i can get recommendations for recycling centers that best fit my availability."],
#  ['user',
#   'i want to link my email account to my profile, so that i can get a temporary password in case i forget my own one.'],
#  ['user',
#   'i want to contact the administrators, so that i can give feedback or ask for help.'],
#  ['admin',
#   'i want to add recycling center information, so that i can keep the database up-to-date over time.'],
#  ['admin',
#   'i want to view user error logs, so that i can fix or review any issues that are being faced by users of the system.'],
#  ['admin',
#   'i want to onboard recycling centers on the platform, so that i can increase information accuracy.'],
#  ['superuser',
#   'i want to update the recycling center information, so that i can provide the latest information about the recycling center.'],
#  ['superuser',
#   "i want to view users' stats, so that i can view in real-time how many users have visited my recycling center information and their recyclable waste."],
#  ['superuser',
#   'i want to reply to user questions, so that i can answer any questions about my recycling center.'],
#  ['admin',
#   'i want to be able to have a dashboard that shows usage stats and locations, so that i can identify the neighbourhoods with the largest number of drop-offs and to try getting more facilities involved.'],
#  ['admin',
#   'i want to be able to communicate directly with facilities, so that i can keep them updated about features we have on our website.'],
#  ['user',
#   'i want to be able to browse through the list of facolities and see which ones are environment-friendly, so that i can know for sure my waste is not going to leave a negative ecological footprint.'],
#  ['recyclingfacility representative',
#   'i want to be able to update my information and the type of material i accept, so that i can avoid any miscommunication with users.'],
#  ['recyclingfacility representative',
#   'i want to have access to user stats and schedules, so that i can adjust my hours and/or upgrade equipment and capacity in order to be able to accomodate larger amounts of recyclable materials.'],
#  ['recyclingfacility',
#   'i want to be able to communicate directly with the site admin and convey any issues or concerns i have, so that they fix them.'],
#  ['data publishing user',
#   'i want to be able to edit a dataset i have published, so that i can correct or enhance existing data.'],
#  ['data publishing user',
#   'i want to be able to edit the model of data i have already imported, so that i can fix bugs or make enhancements in the api built for my data.'],
#  ['data publishing user',
#   'i want to be able to delete a dataset i have published, so that i can remove unwanted data from openspending.'],
#  ['platform administrator',
#   'i want to be able to hide any dataset already added as public, so that i can maintain public/hidden status for other users.'],
#  ['platform administrator',
#   'i want to have a view on all datasets published by all users, so that i can perform management actions on any dataset.'],
#  ['platform administrator',
#   'i want to be able to delete any dataset published, so that i can deal with takedown requests, or clean up test datasets.'],
#  ['data publishing user',
#   'i want to be able to edit the data source of data i have already imported, so that i can fix bugs or make enhancements in the api built for my data.'],
#  ['data publishing user',
#   'i want to have the packager support constants, so that i can model dimensions that may not exist in the source file.'],
#  ['data publishing user',
#   'i want to be able to import data in excel, so that i do not have to convert data formats in order to use the data packager.'],
#  ['data publishing user',
#   'i want to know what my data needs to be able to be visualised on a map, so that i can visualise it on a map.'],
#  ['data publishing user',
#   'i want to be able to import data in json, so that i do not have to convert data formats in order to use the data packager.'],
#  ['data publishing user',
#   'i want to be able to import data from a google spreadsheet, so that i do not have to convert data formats in order to use the data packager.'],
#  ['data publishing user',
#   'i want to be able to import data from fiscal data package descriptor file, so that i do not have to convert data formats in order to use the data packager.'],
#  ['data publishing user',
#   'i want to be able to provide the platform administrator with additional geojson sources, so that i can improve the map-based visualisations of my data.'],
#  ['data consuming user',
#   'i want to be able to filter, sort and aggregate data by multiple dimensions and measures, so that i can get more granular views on the data.'],
#  ['data consuming user',
#   'i want to be able to download a csv of the data that is used in any visualisation i am viewing, so that i can use the data in other tools.'],
#  ['data consuming user',
#   'i want to be able to change the display of all monetary measures across a set of currencies, so that i can understand localised amounts in non-localised figures.'],
#  ['data consuming user',
#   'i want to see textual descriptions that accompany embedded visualisations, so that i can more easily understand what i am viewing.'],
#  ['data consuming user',
#   'i want to be able to share a view state as a url to social networks, so that i can share data that i have found with others.'],
#  ['data consuming user',
#   'i want to be able to download an image ofa particular view state, so that i can use it offline.'],
#  ['data consuming user',
#   'i want to be able to share an image of a particular view state to the social networks that support this, so that i can provide richer context in those communication channels for data i am sharing.'],
#  ['data consuming user',
#   'i want to be able to have stepped zoom on map visualisations, so that i can have better control over the navigation experience inside a map view.'],
#  ['data consuming user',
#   'i want to have consistent use of colour on map visualisations, so that i can better understand the visual logic of the map view.'],
#  ['developer',
#   'i want to be able to customise the brand name and icon, and primary color of all frontend javascript apps, so that i can customise the branding for my own needs.'],
#  ['api user',
#   'i want to be able to understand if a user is a publisher, so that i can offer functionality based on dataset publisher privileges.'],
#  ['api user',
#   'i want to be able to understand if a user is an administrator, so that i can offer functionality based on platform administration privileges.'],
#  ['api user',
#   'i want to be able to get bordering regions|cities when i query a region|city, so that i can provider wider visual context for mapping visualisations.'],
#  ['api user',
#   'i want to be able to dynamically request polygons based on the query made, so that i can provide maps that match the query.'],
#  ['api user',
#   'i want to have a flexible api using hasc codes for countries, regions and cities, so that i can visualise budget data on maps.'],
#  ['api user',
#   'i want to be able to get a csv output of any cube-based query, so that i can use work with tools that read csv.'],
#  ['api user',
#   'i want to be able to get a set of monetary measures transferred to different currencies, so that i can use this in scenarios that might enable comparison by normalisation.'],
#  ['api user',
#   'i want to be able to use metadata to get results from multiple datasets, so that i can build user experiences based on more than one dataset more easily.'],
#  ['api user',
#   'i want to be able to use data to get results from multiple datasets, so that i can build user experiences based on more than one dataset more easily.'],
#  ['api user',
#   'i want to be able to normalise measures by population, so that i work with datasets in reference to their contextual constraints.'],
#  ['api user',
#   'i want to be able to normalise measures by geographical area, so that i work with datasets in reference to their contextual constraints.'],
#  ['api user',
#   'i want to be able to normalise measures by gdp, so i work with datasets in reference to their contextual constraints.'],
#  ['api user',
#   'i want to be able to normalise measures by gini and related socioeconomic indexes, so that i work with datasets in reference to their contextual constraints.'],
#  ['api user',
#   'i want to be able to get a relative percentage of a measure to the total of the dataset it comes from, so that i can build alternative displays of the data.'],
#  ['api user',
#   'i want to be able to persistently store visualisation state in the database, so that such can be shared more easily and contribute to a visualisation gallery.'],
#  ['data publishing user',
#   'i want to have my dataset update automatically as the source file/files changes, so that openspending always shows current data.'],
#  ['openspending community member',
#   'i want to have a blog that highlights any and all projects in the open fiscal space, so that i can relate to openspending.org as the central hub of fiscal openness.'],
#  ['user',
#   'i want to be able to set my own username, so that my data is more easily discoverable.'],
#  ['data publishing user',
#   'i want to be able to add a dataset in a hidden state, so that i can work on a dataset before having it discoverable via openspending user interfaces.'],
#  ['data publishing user',
#   'i want to be able to hide a dataset that i have already added as public, so that i can fix my mistakes or have a dataset primarily for my own use.'],
#  ['data publishing user',
#   'i want to have a view on all the datasets i have published, so that i can perform management actions on my own datasets.'],
#  ['data publishing user',
#   'i want to have a functioning python client, so that i can add data to the datastore in bulk from the command line or my own programs.'],
#  ['openspending community member',
#   'i want to have an app where i can find examples of use of fiscal data visualisations, so that i can find guidance in creating my own with open spending.'],
#  ['data publishing user',
#   'i want to know if my csv file is valid, so that i can fix possible data issues before publishing it on open spending.'],
#  ['data consuming user',
#   "i want to be able to search any dataset published and publicly accessible by their title and metadata, so that i can find the datasets i'm interested in."],
#  ['data consuming user',
#   "i want to visualize by default in treemap, bubble tree, map and pivot table the most recent year when my dataset contain multiple years, so that i'm not confused with the amounts."],
#  ['api user',
#   'i want to be able to change the colors of the embedded visualisations in my own platform, so that i can customize the visualisations.'],
#  ['api user',
#   "i want to be able to change some of the styling of the embedded viewer in my own platform, so that i can brand it to my own organisation's color scheme."],
#  ['platform administrator',
#   'i want to be able to translate the data types hierarchies of the viewer while in embed mode, so that my users can understand the interface in their native language.as a developer, i want to get a data package into node, so that i can start using the data for doing analysis and visualizations.'],
#  ['researcher',
#   'i want to get a data package into julia in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['publisher',
#   'i want to add type information to my data, so that it is more useful to others and can be used better with tools like visualization programs. '],
#  ['publisher',
#   'i want to be able to provide a visualization of data in the data package, so that i can provide my analysis and show my work to users of the data. '],
#  ['researcher',
#   'i want to be able to save new visualizations, so that i can share them with others or include them in the data package. '],
#  ['researcherpublisher',
#   'i want to know that my data conforms to its data package profile, so that i can feel trust in the validity and usefulness of the data. '],
#  ['researcherpublisher',
#   'i want to understand the ways in which my data is invalid, so that i can know how to fix it. '],
#  ['researcher',
#   'i want to get a data package into r in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['researcher',
#   'i want to get a data package into excel in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['researcher',
#   'i want to get a data package into spss in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['researcher',
#   'i want to get a data package into stata in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['researcher',
#   'i want to be able to translate my eml dataset to a data package, so that i can benefit from the wide array of tools available for data packages. '],
#  ['researcher',
#   'i want to get a data package into libreoffice/openoffice in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['developer',
#   'i want to get a data package into python in seconds, so that i can start using the data for doing analysis and visualizations. '],
#  ['developer',
#   'i want a jquery plugin for core data packages, so that i can use it to apply to form control that uses a core dataset for autocompletion. '],
#  ['researcher',
#   'i want to get my excel spreadsheet into a data package, so that i can benefit from better tooling and standardization. '],
#  ['developer',
#   'i want to do exploratory data analysis in r and operationalize that analysis in python, so that i can use the best tool for the job.'],
#  ['developer',
#   'i want to get a data package into clojure in seconds, so that i can start using the data in doing analysis and visualizations. '],
#  ['developer',
#   'i want to get a data package into julia in seconds, so that i can start using the data in doing analysis and visualizations. '],
#  ['developer',
#   'i want to get a data package into c++ in seconds, so that i can start using the data in doing analysis and visualizations. '],
#  ['machine learning expert',
#   'i would like to package ml datasets as data packages, so that i can easily import them into my ml platform, so that i can start using the data in doing analysis. '],
#  ['developer',
#   'i want an elasticsearch integration, so that i can integrate data-packaged data with pipelines that use elasticsearch. '],
#  ['developer',
#   'i want an spss integration, so that i can integrate data-packaged data with pipelines that use spss. '],
#  ['developer',
#   'i want an eprints integration, so that i can integrate data-packaged data with pipelines that use eprints. '],
#  ['developer',
#   'i want a mongo integration, so that i can integrate data-packaged data with pipelines that use mongo. '],
#  ['developer',
#   'i want a dat integration, so that i can integrate data-packaged data with pipelines that use dat. '],
#  ['researchergovernment publisher',
#   'i want to add general reference data to my narrow dataset, so that my dataset is more useful. '],
#  ['researchergovernment publisher',
#   'i want to add general country names to my dataset that only contains country codes, so that my dataset is more readable. '],
#  ['researchergovernment publisher',
#   'i want to add reference data on inflation to my spending dataset, so that the spending lines in my dataset is more understandable. '],
#  ['researchergovernment publisher',
#   'i want to map lines in my dataset using geographic data in my dataset, so that my dataset is more engaging for non-technical users. '],
#  ['researcher',
#   'i want to be able to reference a remote-controlled vocabulary for my dataset, so that i can be sure that column of my dataset are valid against a single shard list of terms. '],
#  ['developer',
#   'i want an dspace integration, so that i can integrate data-packaged data with pipelines that use dspace. '],
#  ['developer',
#   'i want feather integration, so that i can integrate data-packaged data with pipelines that use feather. '],
#  ['developer',
#   'i want hdf5 integration, so that i can integrate data-packaged data with pipelines that use hdf5.'],
#  ['researcher',
#   'working with data, i want an microsoft power bi integration, so that i can import datasets without downloading them locally. '],
#  ['researcherpublisher',
#   'i want an integration with zenodo, so that when i store my dataset in github, i donâ\x80\x99t have to retype descriptive information about my dataset. '],
#  ['publisher',
#   'i would like an integration with open refine, so that i can output cleaned data packages. '],
#  ['researcherpublisher',
#   'i want to publish data packages to ckan, so that my data is findable, and i can have a data api. '],
#  ['researcherdeveloper',
#   'would like the ability import/export from ms-sql, so that i can use data packages in workflows that involve ms-sql. '],
#  ['researcher',
#   'working with data in netcdf, i want netcdf integration, so that i can store my data in plaintext while still retaining its metadata. '],
#  ['researcher',
#   'i want an integration with https://data.mendeley.com/, so that i can validate my data upon ingest to the service.'],
#  ['publisher',
#   'i would like an integration with excel, so that i can output cleaned data packages. '],
#  ['publisher', 'i want to store my data quickly and easily online. '],
#  ['repository manager',
#   'i want a tool that makes it easy for researchers/ users to add basic metadata to their research data, so that it is more findable and therefore useful. '],
#  ['researcherpublisher',
#   'i want validate my data with a minimum of clicks, so that i can feel trust in the validity and usefulness of the data. '],
#  ['publisher',
#   'i want to be able to check that every time i update my data it is still good, so that i can catch errors early and store reliable data. '],
#  ['developerwrangler',
#   'i want to use a command line tool that allows met to validate data, so that i can feel trust in the validity and usefulness of the data quickly and in the context of my command line workflow. '],
#  ['developer',
#   'i want an online service that is connected to my data repository that validates data on update, so that i can delegate data validation to a third party. '],
#  ['government publisher',
#   'i want to make it easy to prove that our published data is valid, so that i can claim that we are living up to our transparency commitments. '],
#  ['civic tech activist',
#   'i want to make it easy to assess the quality of data stored by the government, so that i can make sure that government is living up to its transparency commitments. '],
#  ['publisher',
#   'i want to embed an interactive preview of my data on my site, so that users can be encouraged that this is the correct data for them. '],
#  ['publisher',
#   'i want to embed a preview button on my site, so that users can preview the data and be encouraged that this is the correct data for them.'],
#  ['publisher',
#   'i want to know how many users have previewed a dataset, so that i know how interest in a dataset relates to its actual download numbers. '],
#  ['developer',
#   'i want to customize an existing wizard for my specific type of data, so that i can give my users a great user experience.'],
#  ['publisher',
#   'i want to add useful metadata or add in new data columns to make the dataset more useful. '],
#  ['publisher',
#   'i want to package reproducible steps to get a certain data state, so my methodology is transparent and can be rerun by others. '],
#  ['developerdatawrangler',
#   'i want to store my data package in github and have it automatically stored into ckan, so that i get a data api and my dataset is listed in a relevant catalog. '],
#  ['researcher',
#   'i want a tool that can generate basic statistics about a dataset, so that i can get a quick preview of the data. '],
#  ['developerpublisher',
#   'i want a tool to create an embeddable data summary via iframe, so that i can embed data summaries across sites. '],
#  ['researcher',
#   'i want an app that generates an openrefine reconciliation api endpoint from a tabular data package, so that i can use it to clean messy data. '],
#  ['researcher',
#   'i want an app that create proxy data packages for well know and reliable data, sources, so that i can load high quality data using data package tooling. '],
#  ['repositorymanagerresearcher',
#   'i want an app that acts as a match-making service for packaging data, so that owners are paired with data packagers. '],
#  ['developer',
#   'i would like to create a web socket protocol for frictionless data tools, so that i can easily use data packages with additional data analysis tools. '],
#  ['publisher',
#   'i would like a tool to check data availability persistence after publication. '],
#  ['researcherpublisher',
#   'i want to specify the funding that contributed to the creation of a given dataset, so that funding agencies can identify the funding, source for a given dataset. '],
#  ['researcherpublisher',
#   'i want to add a doi to a dataset, so that i can cite it in papers stored  with the data. '],
#  ['site member',
#   'i want to describe myself on my own page in a semi-structured way, so that others can learn about me.'],
#  ['site member',
#   'i want to fill out an application to become a certified scrum practitioner, so that i can earn that designation.'],
#  ['practitioner',
#   'i want to include additional details about me in my profile page, so that i can showcase my experience.'],
#  ['site member',
#   'i want to fill out an application to become a certified scrum trainer, so that i can teach csm and cspo courses and certify others.'],
#  ['trainer',
#   'i want to include additional details in my profile page about me, so that others can learn about me and decide if i am the right trainer for them.'],
#  ['practitioner',
#   'i want to write an article for the site with a small graphic shown with the article showing my csp or cst status, so that others know my certifications when reading.'],
#  ['trainer',
#   'i want to list my upcoming classes in my profile and include a link to a detailed page about each, so that prospective attendees can find my courses.'],
#  ['site member',
#   'i want to view the profiles of other members, so that i can find others i might want to connect with.'],
#  ['site member',
#   'i want to search for profiles based on a few fields, so that i can find others i might want to connect with.'],
#  ['site member',
# ...
#  ['user',
#   'i want to have that my twitter tweets to appear in neurohub, so that other researchers in the centre can see what i am up to.'],
#  ['user',
#   "i want to view the group's shared calendars via the neurohub nodes' web page as well as on my mobile device."],
#  ['user',
#   'i want to sync events created in neurohub with a web-based calendar such as google calendar.'],
#  ['researcher',
#   'i want to have the ability to insert greek symbols into my logbook entries.'],
#  ['user',
#   'i want to have the ability to move multiple files around and rearrange them using the neurohub file browser while processing data.'],
#  ['researcher',
#   'i want to point my mendeley client at a group-wide shared repository of research papers and get notifications via mendeley when new content is added.'],
#  ['researcher',
#   'i want to have electronic support for keeping track of which data sets were used/output/modified as part of a particular experiment.'],
#  ['user',
#   'i want a mechanism for electronically sharing papers and notes with other researchers, so that we can collaborate effectively.'],
#  ['researcher',
#   "i want to have services to support the long term curation of data, so that i can be sure that data will not get 'lost' with the passage of time."],
#  ['researcher',
#   'i want to have a timeline display of multiple data files and their associated images, so that i can compare the data taken from experiments on particular dates.'],
#  ['researcher',
#   'i want to have remote access to my data for off-site working , so that i can still work effectively while away from the lab.'],
#  ['researcher',
#   'i want to share post-experiment write-ups with other researchers, so that others can more easily replicate my work.'],
#  ['researcher',
#   'i want to collect data as a library of data, which can then be used by one or multiple experiments that are defined at a later stage.'],
#  ['researcher',
#   'i want to indicate within my electronic log book which experimental data is good/bad, hide the bad data, but still keep it in the system just in case it is useful in the future.'],
#  ['researcher',
#   "i want to have the system to provide standard metadata, that all researchers in the centre (and beyond) can use, so that we can better understand each others' data."],
#  ['researcher',
#   'i want to have physiology images to be annotated with standard meta data, so that my data can later be searched for and understood.'],
#  ['researcher',
#   'i want to have the ability to attach standard meta data for behavioural observations (and video), so that my data can later be searched for and understood.'],
#  ['researcher',
#   ' i want to have the ability to attach standard meta data for drug responses, so that my data can later be searched for and understood.'],
#  ['researcher',
#   'i want to have the ability to search for images of cells using standard meta data.'],
#  ['researcher',
#   'i want to have at least some meta data to be automatically inserted when new data is added to the system.'],
#  ['researcher',
#   ' i want to have the ability to attach detailed meta data to the data and entries that i create.'],
#  ['researcher',
#   'i want to have the ability to select a partially pre-populated template that already contains commonly entered meta data while adding new data to the system, so that i do not waste time repeatedly inserting the same meta data over and over again for each individual file or log book entry.'],
#  ['user',
#   'i want to be sure that existing metadata corresponding to the file is not lost when moving a file to a new location.'],
#  ['researcher',
#   'i want to have the ability to form links between objects, for example file a is an analysis of file b, so that data can be searched by type and by association.'],
#  ['researcher',
#   'i want to have the ability to locate experiment files using meta data, regardless of where those files are located.'],
#  ['researcher',
#   'i want to have any data that i have written to the vre to be protected from modification or deletion, so that original data can always be traced back to an experiment and a point in time.'],
#  ['user',
#   ' i want to have the ability to keep my data private on the system, and only share data that i deem should be shared.'],
#  ['researcher',
#   ' i want to have the ability to store all the inputs for an experiment so that the provenance of the results can be verified.'],
#  ['researcher',
#   'i want to have the ability to search for files by file type and format.'],
#  ['researcher',
#   ' i want to have the ability to bulk upload directories and files with minimal effort.'],
#  ['researcher',
#   'i want to associate meta data to the group as a whole at some point in time after the bulk upload has completed, so that i have a period of time to reflect on suitable values for the meta data.'],
#  ['user',
#   ' i want to have the ability to change the sharing and ownership of multiple files.'],
#  ['researcher',
#   ' i want to have the ability to restrict the data i share to certain researchers or groups of researchers.'],
#  ['researcher',
#   ' i want to have the ability to locate and access data that colleagues want to share.'],
#  ['researcher',
#   ' i want to have the ability to interact with a revision control system so that i can keep track of changes to files over time.'],
#  ['juniorresearcher',
#   ' i want to have the ability to harvest knowledge from within the group, so that i can learn from more experienced researchers.'],
#  ['researcher',
#   'i want to secure remote access to the neurohub node when working away from the laboratory'],
#  ['researcher',
#   'i want to have a group-level repository for sharing papers/reviews/comments with other researchers.'],
#  ['researcher',
#   'i want to have the details of the workflow plan as well as the execution history and results recorded in neurohub while executing a workflowas an olderperson, i want to know exactly what alfred does with my personal data, and share it only on my specific permission. '],
#  ['olderperson',
#   'i want to receive information from alfred by speech technology. '],
#  ['olderperson', 'i want to use only well-visible buttons.'],
#  ['olderperson',
#   'i want to use alfred as much as possible with speech interaction.'],
#  ['olderperson',
#   'i want to always keep control on the activities of alfred. '],
#  ['olderperson', 'i want to be able to manage my privacy and data settings. '],
#  ['olderperson',
#   'i want to have everything preinstalled, so that i do not have to set up alfred by myself.'],
#  ['olderperson',
#   'i want to have a small alfred device that is wearable and easy to carry with me.'],
#  ['olderperson',
#   'i want to have alfred on all my computers, tablets and phone.'],
#  ['olderperson',
#   'i want to have alfred on a bracelet or a necklace, so that i can always wear him with me. '],
#  ['olderperson',
#   'i want to have clear instructions and service after sales that guide me if i have trouble in using alfred.'],
#  ['olderperson',
#   'i want to have an alfred device that speaks very slowly and clearly.'],
#  ['olderperson', 'i want to have an alfred device that only reacts to me.'],
#  ['olderperson',
#   'i want to have an alfred device that only listens to me when i ask it to. '],
#  ['olderperson',
#   'i want to have an introduction conversation with alfred, so that i can learn everything about him and he about me. '],
#  ['olderperson',
#   'i want to buy alfred in a senior shop with special client support. '],
#  ['olderperson', 'i want to buy alfred for a low price. '],
#  ['olderperson',
#   'i want to receive visual support, especially when looking at a list, map or agenda.'],
#  ['olderperson', 'i want to use alfred to pay for small amounts.'],
#  ['olderperson',
#   'i want to have a very good battery for alfred so i can keep him on the whole day.'],
#  ['olderperson',
#   'i want to have an alfred device that informs me about a low battery when leaving the house. '],
#  ['olderperson',
#   'i want to have an alfred device that can be easily adapted for user that have visual or hearing troubles.'],
#  ['olderperson',
#   'i want to have an alfred device that can be easily adapted for user that have visual troubles. '],
#  ['olderperson',
#   'i want to have an alfred device that can be easily adapted for user that have hearing trouble. '],
#  ['olderperson',
#   'i want to have an alfred device that repeats the last phrase. '],
#  ['olderperson', 'i want to be able to zoom into visual content. '],
#  ['olderperson',
#   'i want to have an alfred device that responds to the changing demand of the users by offering new apps in the alfredo platform.'],
#  ['olderperson',
#   'i want to have an alfred device that helps me to communicate with my friends and family. '],
#  ['olderperson', 'i want to have video conversation with others. '],
#  ['medicalcaregiver', 'i want to have videophone. '],
#  ['olderperson',
#   'i want to have an aflred device that encourages its users for real interaction between humans and not only with ict tools. '],
#  ['olderperson',
#   'i want to have an alfred device that provides me with information about existing apps that corresponds to my interests. '],
#  ['olderperson',
#   'i want to be able to customize my preferences in the different functionalities of the solution.'],
#  ['medicalcaregiver',
#   'i want to have a simple alfred unit that is expandable in is functions. '],
#  ['olderperson', 'i want to have my data stored directly on the phone.'],
#  ['olderperson',
#   'i want to receive a wake up call from alfred in the morning checking on me if i am ok.'],
#  ['olderperson',
#   'i want to receive day and night rythm support with agenda reminders. '],
#  ['olderperson', 'i want to receive support to use the public transport. '],
#  ['olderperson', 'i want to use alfred for navigation. '],
#  ['olderperson',
#   'i want to use alfred for touristic walks and indications with explanations on historical and cultural sights. '],
#  ['olderperson', 'i want to receive support to have a taxi on time. '],
#  ['olderperson',
#   'i want to use alfred to see who is standing at my door and open the door. '],
#  ['olderperson',
#   'i want to use alfred to pick the phone sooner up when i am at home. '],
#  ['olderperson', 'i want to use alfred to turn on/off the lights. '],
#  ['olderperson', 'i want to use alfred to control the heating. '],
#  ['olderperson', 'i want to use alfred to control the tv and radio. '],
#  ['olderperson', 'i want to use alfred to watch movies. '],
#  ['olderperson', 'i want to use alfred to hear about the news. '],
#  ['olderperson',
#   'i want to use alfred to contact help in case of an emergency. '],
#  ['medicalcaregiver', 'i want to use video calls in case of emergency. '],
#  ['olderperson',
#   'i want to have alfred contact the nearest caregiver when i ask alfred for urgent help. '],
#  ['olderperson',
#   'i want to receive a message when my home care nurse is on her way. '],
#  ['olderperson', 'i want to receive a medicine reminder from alfred. '],
#  ['olderperson',
#   'i want to be able to see whether i already have taken my pills, so that i can avoid an overdose. '],
#  ['medicalcaregiver',
#   'i want to be able to see if the patient has taken her medicine. '],
#  ['olderperson', 'i want to use alfred to do my grocery shopping. '],
#  ['olderperson', 'i want to use alfred to send messages. '],
#  ['olderperson',
#   'i want to have alfred to detect falls and send an emergency to a specific contact. '],
#  ['olderperson', 'i want to have alfred to suggest healthy recipes. '],
#  ['olderperson',
#   'i want to have alfred ask spontaneous questions but it would be better to programme it during certain times of the day. '],
#  ['olderperson',
#   'i want to have alfred to initiate questions, but it should be in the domains of my interest such as cinema, exhibitions, cooking. '],
#  ['olderperson', 'i want to be able to call someone with alfred. '],
#  ['olderperson',
#   'i want to activate the vocal interaction mode of alfred by pushing a specific button. '],
#  ['olderperson',
#   'i want to use alfred to maintain my contact list in my phone. '],
#  ['olderperson', 'i want to use alfred to manage my agenda. '],
#  ['olderperson', 'i want to insert my meetings into alfred using speech. '],
#  ['olderperson', 'i want to receive reminders on my appointments. '],
#  ['olderperson',
#   'i want to receive a reminder from alfred on all the things i need to bring with me when i leave the house. '],
#  ['socialcaregiver',
#   'i want alfred to remind me of the things i need to bring to the person i care for. '],
#  ['olderperson',
#   'i want to use alfred to set up social groups of people with similar diseases. '],
#  ['olderperson',
#   'i want to use alfred to contact people from my own circle. '],
#  ['olderperson',
#   'i want to use alfred to learn about art expositions or a museum. '],
#  ['olderperson',
#   'i want to use alfred to learn about all the social activities that are organized in my neighborhood. '],
#  ['olderperson',
#   'i want to use alfred to get a personalized invitation to a social event, so that it motivates more to go. '],
#  ['olderperson',
#   'i want to use alfred to navigate to an event or concert and help me when i am lost. '],
#  ['olderperson',
#   'i want to use alfred to help me navigate despite my mild cognitive impairments. '],
#  ['olderperson', 'i want to be able to pay for small amounts. '],
#  ['olderperson',
#   'i want to use alfred to organize a meeting with a group of friends at a certain place. '],
#  ['olderperson', 'i want to play online games together with other users. '],
#  ['olderperson',
#   'i want to get suggestions for sports classes in my neighbourhood. '],
#  ['olderperson',
#   'i want to have alfred to enable me to have face to face contacts as well, so that i do not just have virtual contacts over alfred. '],
#  ['olderperson', 'i want to help me to control my body weight. '],
#  ['olderperson', 'i want to just press one button to call my caregiver. '],
#  ['olderperson', 'i want to decide who has access to my vital data. '],
#  ['medicalcaregiver',
#   'i want to be sure that the user can decide who has access to her data. '],
#  ['olderperson',
#   'i want to have the wearables with integrated sensors to look good and not to be stigmatizing. '],
#  ['olderperson', 'i want to see my vital parameters myself on the phone. '],
#  ['olderperson', 'i want to have the alfred shirt to look good. '],
#  ['olderperson',
#   'i want to have the alfred shirt has to be non stigmatizing. '],
#  ['medicalcaregiver',
#   "i want to have alfred to be able to determine the user's blood pressure. "],
#  ['medicalcaregiver',
#   "i want to have alfred to be able to determine the user's body temperature. "],
#  ['medicalcaregiver',
#   "i want to have alfred to be able to determine the user's heart rate. "],
#  ['medicalcaregiver',
#   "i want to have alfred to be able to determine the user's breathing frequency. "],
#  ['medicalcaregiver',
#   'i want to have feedback on the activity level of the user. '],
#  ['medicalcaregiver', 'i want to locate the alfred user. '],
#  ['socialcaregiver',
#   'i want to have alfred to be able to recognize pain and or stress by using skin conduction sensors. '],
#  ['socialcaregiver', 'i want to have a step counter included into alfred. '],
#  ['olderperson',
#   'i want to have alfred to give me goals and missions that encourage me to do new activities and exercises and to go out. '],
#  ['olderperson',
#   'i want to have alfred to set limits in the games duration as i get bored easily. '],
#  ['olderperson', 'i want to play games where i can use my imagination. '],
#  ['olderperson',
#   'i want to do guided exercises with alfred and alfred should also use sensors to capture health data while i am doing exercises. '],
#  ['olderperson', 'i want to have games that include my favourite sports. '],
#  ['olderperson', 'i want to receive suggestions about local sport classes. '],
#  ['olderperson',
#   'i want to have alfred to remind me to keep a good body posture. '],
#  ['medicalcaregiver',
#   'i want to have alfred to remind people to exercise regularly. '],
#  ['olderperson',
#   'i want to receive specific tips how to reduce my health impairments without medication. '],
#  ...]

# %%
#converting data into dataframe
df = pd.DataFrame(columns=['user_role','user_story'],data=data_list)

df.head()
# Out:
#      user_role                                         user_story
# 0    data user  i want to have the 12-19-2017 deletions proces...
# 1  ui designer  i want to redesign the resources page, so that...
# 2  ui designer  i want to report to the agencies about user te...
# 3  ui designer  i want to move on to round 2 of dabs or fabs l...
# 4  ui designer  i want to move on to round 2 of homepage edits...

# %% [markdown]
# ##### 2. Identify the tasks for given stakeholder

# %%
df['user_role'].value_counts()
# Out:
# user                                                   149
# researcher                                             111
# olderperson                                             95
# archivist                                               89
# developer                                               61
#                                                       ...
# mike                                                     1
# advertiser                                               1
# site member who has read a teaser on the front page      1
# technical staff member                                   1
# research centre director                                 1
# Name: user_role, Length: 208, dtype: int64

# %% [markdown]
# a. Data management

# %%
df_data_management = df[df['user_story'].str.contains('data management')]

df_data_management
# Out:
#                  user_role                                         user_story
# 714       data contributor  i want to refer to the disaster recovery plan ...
# 1124                funder  i want to be able to read the costs for data m...
# 1126           stakeholder  i want to know when the data management plan w...
# 1131          data manager  i want to know the time plan for collecting da...
# 1176  faculty data steward  i want to see the sections on costing, so that...
# 1177  faculty data steward  i want to see the sections on roles, so that i...
# 1178  faculty data steward  i want to see the sections on responsibilities...
# 1258             depositor  i want to allow others to deposit on my behalf...

# %% [markdown]
# b. Data store

# %%
df_data_store = df[df['user_story'].str.contains('data store')]

df_data_store
# Out:
#                 user_role                                         user_story
# 306   civic tech activist  i want to make it easy to assess the quality o...
# 928           olderperson  i want to have my data stored directly on the ...
# 1249            depositor  i want to link to data stored in external repo...

# %% [markdown]
# c. analysis

# %%
df_analysis = df[df['user_story'].str.contains('analysis')]

df_analysis
# Out:
#                     user_role  \
# 257    platform administrator
# 258                researcher
# 260                 publisher
# 264                researcher
# 265                researcher
# 266                researcher
# 267                researcher
# 269                researcher
# 270                 developer
# 273                 developer
# 274                 developer
# 275                 developer
# 276                 developer
# 277   machine learning expert
# 319                 developer
# 613                  consumer
# 847                      user
# 879                researcher
# 1443               researcher
# 1625         zooniverse admin
# 1638         zooniverse admin
#
#                                              user_story
# 257   i want to be able to translate the data types ...
# 258   i want to get a data package into julia in sec...
# 260   i want to be able to provide a visualization o...
# 264   i want to get a data package into r in seconds...
# 265   i want to get a data package into excel in sec...
# 266   i want to get a data package into spss in seco...
# 267   i want to get a data package into stata in sec...
# 269   i want to get a data package into libreoffice/...
# 270   i want to get a data package into python in se...
# 273   i want to do exploratory data analysis in r an...
# 274   i want to get a data package into clojure in s...
# 275   i want to get a data package into julia in sec...
# 276   i want to get a data package into c++ in secon...
# 277   i would like to package ml datasets as data pa...
# 319   i would like to create a web socket protocol f...
# 613   i want to be able to get the data for a data p...
# 847   i want to store worm behaviour videos with an ...
# 879   i want to have the ability to form links betwe...
# 1443  i want to see common material across collectio...
# 1625  i want to assess how interesting or appealing ...
# 1638  i want to perform automatic worm motion analys...

# %% [markdown]
# d. cleaning

# %%
df_cleaning = df[df['user_story'].str.contains('cleaning')]

df_cleaning
# Out:
# Empty DataFrame
# Columns: [user_role, user_story]
# Index: []

# %% [markdown]
# e. privacy

# %%
df_privacy = df[df['user_story'].str.contains('privacy')]

df_privacy
# Out:
#                        user_role  \
# 899                  olderperson
# 1044                     trainer
# 1172  institutional data manager
# 1181                data manager
#
#                                              user_story
# 899   i want to be able to manage my privacy and dat...
# 1044  i want to have a view that is attached to thei...
# 1172  i want to know about the privacy and security ...
# 1181  i want to plan the anonymization of data, so t...

# %% [markdown]
# ##### 3. Visualization of frequently occurred words based on stakeholders

# %%
import matplotlib 
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Academic\Sem 08 Natural Language Processing\18xd82-nlp-hackathon\18pd26-hackathon.ipynb Cell 28' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Academic/Sem%2008%20Natural%20Language%20Processing/18xd82-nlp-hackathon/18pd26-hackathon.ipynb#ch0000027?line=0'>1</a> import matplotlib
#       <a href='vscode-notebook-cell:/d%3A/Academic/Sem%2008%20Natural%20Language%20Processing/18xd82-nlp-hackathon/18pd26-hackathon.ipynb#ch0000027?line=1'>2</a> from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
text = " ".join(cat.split()[1] for cat in df.category)
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
